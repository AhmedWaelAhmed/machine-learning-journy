# %% [markdown]
# how to use packages
# to help arrange a lot of modules

# %% [markdown]
# pip  manager

# %% [markdown]
# we will make to modules

# %%
import module_1  #if file module is not in same folder we will use import filename.module_1
