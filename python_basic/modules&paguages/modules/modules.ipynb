# %% [markdown]
# scripts
# دوال تتكرر وانا مش عايز كده
# نعمل ملف واستدعيه جواه الدوال اللي محتاجها

# %%
# we will create a file use.py

# %%
import util
util.greet("Alice")
# we can know the list of folder python use to search for modules by
import sys
print(sys.path)  # list of folder python use to search for modules
# knowing all varaibles and functions defined in a module using global 
print(dir(util))  # list of all varaibles and functions defined in util module
# Out:
# ['/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/home/ahmed/Desktop/hassob_journy/machine-learning-journy/env/lib/python3.10/site-packages']
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'car', 'greet', 'names']

# %%
# import with out writhing the module name
from util import greet, car, names
greet("Bob")
my_car = car("Toyota", "Corolla")
print(my_car.make)
print(names)
# Out:
# Toyota
# ['Alice', 'Bob', 'Charlie']

# %% [markdown]
# if we have same name function in the file which we call the function in we can
# change name of the file function name like

# %%
# also can change file name import util as my_util if name is very tall
from util import greet as grt_name
def greet():
    print("same name function")
print(grt_name("ahmed"))
greet()
# Out:
# Hello, ahmed!
# same name function

# %%
import util

# %% [markdown]
# 1. القاعدة الذهبية للمتغير __name__: بايثون يعطي كل ملف "بطاقة تعريف" اسمها __name__، وتتغير قيمتها حسب طريقة استخدامك للملف:
#
# الحالة الأولى: التشغيل المباشر (المدير)
#
# الأمر: python3 util.py
#
# قيمة المتغير: "__main__"
#
# النتيجة: بايثون ينفذ كل شيء، بما في ذلك الكود الموجود داخل شرط if.
#
# الهدف: تستخدمها لتجربة واختبار الكود الخاص بك.
#
# الحالة الثانية: الاستيراد (قطعة غيار)
#
# الأمر: import util (داخل كود آخر أو التيرمينال)
#
# قيمة المتغير: اسم الملف نفسه ("util")
#
# النتيجة: بايثون يتجاهل شرط if وينفذ الدوال والمتغيرات العامة فقط.
#
# الهدف: استخدام الدوال في برامج أخرى دون تشغيل كود الاختبارات.
